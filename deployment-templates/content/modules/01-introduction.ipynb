# %% [markdown]
# # Module 1: Introduction - Practice Notebook
#
# This notebook accompanies [[01-introduction|Module 1 notes]].
#
# Run each cell to practice the concepts.

# %%
# Welcome! This is your first code cell.
# Click in this cell and press Shift+Enter to run it.

print("Hello, learner!")
print("You've successfully run your first cell.")

# %% [markdown]
# ## Basic Operations
#
# Let's try some basic Python operations:

# %%
# Basic arithmetic
x = 10
y = 5

print(f"x + y = {x + y}")
print(f"x - y = {x - y}")
print(f"x * y = {x * y}")
print(f"x / y = {x / y}")

# %% [markdown]
# ## Your Turn!
#
# Modify the cell below to practice what you've learned:

# %%
# Exercise: Calculate the area of a rectangle
# Hint: area = width * height

width = 8
height = 5

# Your code here:
area = ???

print(f"The area is: {area}")

# %% [markdown]
# ---
#
# **Next:** [[02-data-basics.ipynb|Continue to Module 2 notebook]]
